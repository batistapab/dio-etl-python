# %%
import pandas as pd

# %%
df = pd.read_csv('ocorrencia_2010_2020.csv', sep=";", parse_dates=['ocorrencia_dia'], dayfirst=True)
#Informamos o arquivo a ser utilizado, tipo de separador e conversão do campo ocorrencia_dia para o tipo data
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 ****     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 ****     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes
# 0        06:00:00                    0
# 1        11:05:00                    0
# ...

# %% [raw]
# #df.loc[1, 'ocorrencia_cidade']

# %% [raw]
# #df.loc[1:3]

# %% [raw]
# #Obter as linhas 10 e 40
# #df.loc[[10,40]]

# %% [raw]
# #Obter apenas a coluna ocorrencia_cidade
# #df.loc[:, 'ocorrencia_cidade']

# %% [raw]
# #Verificar se os dados de uma coluna são exclusivos
# #df.codigo_ocorrencia.is_unique

# %% [raw]
# #Definir a coluna codigo_ocorrencia como índice no dataframe
# df.set_index('codigo_ocorrencia', inplace=True)

# %% [raw]
# df.head()

# %% [raw]
# #df.loc[40324]

# %% [raw]
# #Excluir indice atual
#
# df.reset_index(drop=True, inplace=True)

# %% [raw]
# #Alterar os dados da coluna na posição 0
# #df.loc[0,'ocorrencia_aerodromo'] = ''

# %% [raw]
# #df.head(1)

# %% [raw]
# #Alterar os dados de todas as colunas da linha 1
# #df.loc[1]=20

# %% [raw]
# #df.head(2)

# %% [raw]
# #Alterar os dados de todas as linhas da coluna
# df.loc[:, 'total_recomendacoes'] = 10

# %%
df.head(10)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
# 5              39807               39807                INCIDENTE
# 6              40215               40215                INCIDENTE
# 7              39707               39707          INCIDENTE GRAVE
# 8              39156               39156          INCIDENTE GRAVE
# 9              39711               39711          INCIDENTE GRAVE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 ****     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# ...

# %%
#Uma forma de preservar uma coluna é criar um backup
#df['ocorrencia_uf_bkp'] = df.ocorrencia_uf

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 ****     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 ****     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes
# 0        06:00:00                    0
# 1        11:05:00                    0
# ...

# %%
df.loc[df.ocorrencia_uf== 'SP', ['ocorrencia_classificacao']] = 'GRAVE'

# %%
#Pesquisar apenas ocorrências que ocorreram em SP
df.loc[df.ocorrencia_uf== 'SP']
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 11                40069               40069                    GRAVE
# 16                39809               39809                    GRAVE
# 18                39828               39828                    GRAVE
# 26                39847               39847                    GRAVE
# 27                39768               39768                    GRAVE
# ...                 ...                 ...                      ...
# 5704              79739               79739                    GRAVE
# 5705              79705               79705                    GRAVE
# 5715              79718               79718                    GRAVE
# 5742              79800               79800                    GRAVE
# 5747              79804               79804                    GRAVE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %% [raw]
# ##Tratamento dos dados
#
# ocorrencia_uf
# **
#
# ocorrencia_aerodromo
# ###!
# ####
# ****
# *****
#
# ocorrencia_hora
# NULL

# %%
#df.loc[df.ocorrencia_aerodromo == '****', ['ocorrencia_aerodromo']] = pd.NA

# %%
#df.head()

# %%
df.replace(['**','###!','####','****','**** ','*****'],pd.NA, inplace=True)

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 <NA>     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 <NA>     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes
# 0        06:00:00                    0
# 1        11:05:00                    0
# ...

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  1
# ocorrencia_aerodromo        2349
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %% [raw]
# df.isnull().sum()

# %%
df.replace([10], pd.NA, inplace=True)

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  1
# ocorrencia_aerodromo        2349
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            2
# dtype: int64

# %%
df.fillna(value={'total_recomendacoes':10}, inplace=True)

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  1
# ocorrencia_aerodromo        2349
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
df['ocorrencia_uf_bkp'] = df.ocorrencia_uf

# %%
df.head()
# Out:
#   codigo_ocorrencia codigo_ocorrencia2 ocorrencia_classificacao  \
# 0             40211              40211                INCIDENTE
# 1             40349              40349                INCIDENTE
# 2             40351              40351                INCIDENTE
# 3             39527              39527                 ACIDENTE
# 4             40324              40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 <NA>     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 <NA>     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes ocorrencia_uf_bkp
# 0        06:00:00                    0                RJ
# ...

# %%
df.drop(['ocorrencia_uf_bkp'], axis=1)
# Out:
#      codigo_ocorrencia codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                40211              40211                INCIDENTE
# 1                40349              40349                INCIDENTE
# 2                40351              40351                INCIDENTE
# 3                39527              39527                 ACIDENTE
# 4                40324              40324                INCIDENTE
# ...                ...                ...                      ...
# 5748             79757              79757          INCIDENTE GRAVE
# 5749             79802              79802                INCIDENTE
# 5750             79756              79756          INCIDENTE GRAVE
# 5751             79844              79844                INCIDENTE
# 5752             79844              79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         RIO DE JANEIRO            RJ                 <NA>     2010-01-03
# ...

# %% [raw]
# df.dropna(subset=['ocorrencia_aerodromo'])

# %%
df.drop_duplicates()
# Out:
#      codigo_ocorrencia codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                40211              40211                INCIDENTE
# 1                40349              40349                INCIDENTE
# 2                40351              40351                INCIDENTE
# 3                39527              39527                 ACIDENTE
# 4                40324              40324                INCIDENTE
# ...                ...                ...                      ...
# 5747             79804              79804                    GRAVE
# 5748             79757              79757          INCIDENTE GRAVE
# 5749             79802              79802                INCIDENTE
# 5750             79756              79756          INCIDENTE GRAVE
# 5751             79844              79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         RIO DE JANEIRO            RJ                 <NA>     2010-01-03
# ...
